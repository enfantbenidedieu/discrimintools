# %% [markdown]
# ## CANDISC - vins dataset

# %%
#disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")
from great_tables import GT, html
def print_dt(data,title=None,subtitle=None,rowname=None,digits=4):
    dt = (GT(data=data.round(digits).rename_axis(rowname).reset_index())
          .tab_header(title=title, subtitle=subtitle))
    return dt

# %% [markdown]
# ### vins dataset

# %%
#vins dataset
from discrimintools.datasets import load_vins
D = load_vins()
(
    GT(D.head().rename_axis("Année").reset_index())
    .tab_header(title=html("<b>Vins Bordeaux training data</b>"))
)
# Out:
# GT(_tbl_data=   Année  Temperature  Soleil  Chaleur  Pluie   Qualite
# 0   1924         3064    1201       10    361     Moyen
# 1   1925         3000    1053       11    338  Mediocre
# 2   1926         3155    1133       19    393     Moyen
# 3   1927         3085     970        4    467  Mediocre
# 4   1928         3245    1258       36    294       Bon, _body=<great_tables._gt_data.Body object at 0x00000181E9DB1C10>, _boxhead=Boxhead([ColInfo(var='Année', type=<ColInfoTypeEnum.default: 1>, column_label='Année', column_align='right', column_width=None), ColInfo(var='Temperature', type=<ColInfoTypeEnum.default: 1>, column_label='Temperature', column_align='right', column_width=None), ColInfo(var='Soleil', type=<ColInfoTypeEnum.default: 1>, column_label='Soleil', column_align='right', column_width=None), ColInfo(var='Chaleur', type=<ColInfoTypeEnum.default: 1>, column_label='Chaleur', column_align='right', column_width=None), ColInfo(var='Pluie', type=<ColInfoTypeEnum.default: 1>, column_label='Pluie', column_align='right', column_width=None), ColInfo(var='Qualite', type=<ColInfoTypeEnum.default: 1>, column_label='Qualite', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181E9A0D3D0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Vins Bordeaux training data</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EA480F10>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EA4830D0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EA480C10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', t ...

# %%
#split into X and y
y, X = D["Qualite"], D.drop(columns=["Qualite"])

# %% [markdown]
# ### `instanciation & training`

# %%
from discrimintools import CANDISC
clf = CANDISC(n_components=2,classes=("Mediocre","Moyen","Bon"))

# %% [markdown]
# #### `fit` function

# %%
#fit function
clf.fit(X,y)
# Out:
# CANDISC(classes=('Mediocre', 'Moyen', 'Bon'))

# %% [markdown]
# #### `fit_transform` function

# %%
#fit_transform function
print_dt(clf.fit_transform(X,y).head(),rowname="Annee",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=   Annee    Can1    Can2
# 0   1924 -0.8826 -0.8715
# 1   1925 -2.3255 -0.0942
# 2   1926 -0.9949  0.8330
# 3   1927 -2.7269  0.2472
# 4   1928  0.7436  1.7212, _body=<great_tables._gt_data.Body object at 0x00000181C53F1250>, _boxhead=Boxhead([ColInfo(var='Annee', type=<ColInfoTypeEnum.default: 1>, column_label='Annee', column_align='right', column_width=None), ColInfo(var='Can1', type=<ColInfoTypeEnum.default: 1>, column_label='Can1', column_align='right', column_width=None), ColInfo(var='Can2', type=<ColInfoTypeEnum.default: 1>, column_label='Can2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA41AF90>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EA408E90>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EA0CFC10>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181C6CA8E90>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weig ...

# %% [markdown]
# #### `decision_function` function

# %%
#decision_function function
print_dt(clf.decision_function(X).head(),rowname="Annee",title=html("<b>Fonction de déçision</b>"))
# Out:
# GT(_tbl_data=   Annee  Mediocre   Moyen      Bon
# 0   1924   -2.3545 -1.7220  -6.2956
# 1   1925   -1.1215 -4.2710 -11.0852
# 2   1926   -1.8165 -2.6855  -6.1432
# 3   1927   -1.2515 -5.5451 -12.8843
# 4   1928   -6.1506 -3.8028  -3.1287, _body=<great_tables._gt_data.Body object at 0x00000181EA426810>, _boxhead=Boxhead([ColInfo(var='Annee', type=<ColInfoTypeEnum.default: 1>, column_label='Annee', column_align='right', column_width=None), ColInfo(var='Mediocre', type=<ColInfoTypeEnum.default: 1>, column_label='Mediocre', column_align='right', column_width=None), ColInfo(var='Moyen', type=<ColInfoTypeEnum.default: 1>, column_label='Moyen', column_align='right', column_width=None), ColInfo(var='Bon', type=<ColInfoTypeEnum.default: 1>, column_label='Bon', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA3F4110>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Fonction de déçision</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EA426D50>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EA427190>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EA427750>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', ...

# %% [markdown]
# #### `eval_predict` function

# %%
#eval_predict function
eval_train = clf.eval_predict(X,y,verbose=True)
# Out:
# Observation Profile:
#                         Read  Used
# Number of Observations    34    34
#
# Number of Observations Classified into Qualite:
# prediction  Mediocre  Moyen  Bon  Total
# Qualite
# Mediocre          10      2    0     12
# Moyen              1      8    2     11
# Bon                0      2    9     11
# Total             11     12   11     34
#
# Percent Classified into Qualite:
# prediction   Mediocre      Moyen        Bon  Total
# Qualite
# Mediocre    83.333333  16.666667   0.000000  100.0
# Moyen        9.090909  72.727273  18.181818  100.0
# Bon          0.000000  18.181818  81.818182  100.0
# Total       32.352941  35.294118  32.352941  100.0
# Priors       0.352941   0.323529   0.323529    NaN
#
# Error Count Estimates for Qualite:
#         Mediocre     Moyen       Bon     Total
# Rate    0.166667  0.272727  0.181818  0.205882
# Priors  0.352941  0.323529  0.323529       NaN
#
# Classification Report for Qualite:
#               precision    recall  f1-score    support
# Mediocre       0.909091  0.833333  0.869565  12.000000
# Moyen          0.666667  0.727273  0.695652  11.000000
# Bon            0.818182  0.818182  0.818182  11.000000
# accuracy       0.794118  0.794118  0.794118   0.794118
# macro avg      0.797980  0.792929  0.794466  34.000000
# weighted avg   0.801248  0.794118  0.796675  34.000000

# %% [markdown]
# #### `pred_table` function

# %%
#pred_table function
print_dt(clf.pred_table(X,y),rowname="Reference",title=html("<b>Confusion matrix</b>"))
# Out:
# GT(_tbl_data=prediction Reference  Mediocre  Moyen  Bon
# 0           Mediocre        10      2    0
# 1              Moyen         1      8    2
# 2                Bon         0      2    9, _body=<great_tables._gt_data.Body object at 0x00000181EA4AF110>, _boxhead=Boxhead([ColInfo(var='Reference', type=<ColInfoTypeEnum.default: 1>, column_label='Reference', column_align='left', column_width=None), ColInfo(var='Mediocre', type=<ColInfoTypeEnum.default: 1>, column_label='Mediocre', column_align='right', column_width=None), ColInfo(var='Moyen', type=<ColInfoTypeEnum.default: 1>, column_label='Moyen', column_align='right', column_width=None), ColInfo(var='Bon', type=<ColInfoTypeEnum.default: 1>, column_label='Bon', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA3F2890>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Confusion matrix</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EA3E7A10>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EA486E90>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EA4CD410>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', typ ...

# %% [markdown]
# #### `predict` function

# %%
#predict function
print_dt(clf.predict(X).to_frame().head(),rowname="Annee",title=html("<b>Prediction</b>"))
# Out:
# GT(_tbl_data=   Annee prediction
# 0   1924      Moyen
# 1   1925   Mediocre
# 2   1926   Mediocre
# 3   1927   Mediocre
# 4   1928        Bon, _body=<great_tables._gt_data.Body object at 0x00000181EA499F90>, _boxhead=Boxhead([ColInfo(var='Annee', type=<ColInfoTypeEnum.default: 1>, column_label='Annee', column_align='right', column_width=None), ColInfo(var='prediction', type=<ColInfoTypeEnum.default: 1>, column_label='prediction', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA4DF610>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Prediction</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EA498BD0>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EA499690>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EA498A90>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=Tru ...

# %% [markdown]
# #### `predict_proba` fonction

# %%
#predict_proba function
print_dt(clf.predict_proba(X).head(),rowname="Annee",title=html("<b>Predicted probabilities</b>"))
# Out:
# GT(_tbl_data=   Annee  Mediocre   Moyen     Bon
# 0   1924    0.3446  0.6487  0.0067
# 1   1925    0.9588  0.0411  0.0000
# 2   1926    0.6980  0.2927  0.0092
# 3   1927    0.9865  0.0135  0.0000
# 4   1928    0.0313  0.3270  0.6417, _body=<great_tables._gt_data.Body object at 0x00000181EA4EAD10>, _boxhead=Boxhead([ColInfo(var='Annee', type=<ColInfoTypeEnum.default: 1>, column_label='Annee', column_align='right', column_width=None), ColInfo(var='Mediocre', type=<ColInfoTypeEnum.default: 1>, column_label='Mediocre', column_align='right', column_width=None), ColInfo(var='Moyen', type=<ColInfoTypeEnum.default: 1>, column_label='Moyen', column_align='right', column_width=None), ColInfo(var='Bon', type=<ColInfoTypeEnum.default: 1>, column_label='Bon', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA4E9410>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Predicted probabilities</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EA4EB710>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EA4EB650>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EA4EB990>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value ...

# %% [markdown]
# #### `score` function

# %%
#score function
print("Accuracy : {}%".format(100*round(clf.score(X,y),2)))
# Out:
# Accuracy : 79.0%

# %%
#error rate
print("Error rate : {}%".format(100-100*round(clf.score(X,y),2)))
# Out:
# Error rate : 21.0%

# %% [markdown]
# #### `transform` function

# %%
#transform function
print_dt(clf.transform(X).head(),rowname="Annee",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=   Annee    Can1    Can2
# 0   1924 -0.8826 -0.8715
# 1   1925 -2.3255 -0.0942
# 2   1926 -0.9949  0.8330
# 3   1927 -2.7269  0.2472
# 4   1928  0.7436  1.7212, _body=<great_tables._gt_data.Body object at 0x00000181EA4FF410>, _boxhead=Boxhead([ColInfo(var='Annee', type=<ColInfoTypeEnum.default: 1>, column_label='Annee', column_align='right', column_width=None), ColInfo(var='Can1', type=<ColInfoTypeEnum.default: 1>, column_label='Can1', column_align='right', column_width=None), ColInfo(var='Can2', type=<ColInfoTypeEnum.default: 1>, column_label='Can2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA4FCF90>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EA4FFA10>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EA4FD010>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EA4FF1D0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weig ...

# %% [markdown]
# ### Discriminant informations
#
# #### Summary Information

# %%
#summary information
print_dt(clf.summary_.infos,rowname="",title=html("<b>Summary Information</b>"))
# Out:
# GT(_tbl_data=                  infos  Value                  DF  DF value
# 0  0  Total Sample Size     34            DF Total        33
# 1  1          Variables      4   DF Within Classes        31
# 2  2            Classes      3  DF Between Classes         2, _body=<great_tables._gt_data.Body object at 0x00000181EA508750>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='infos', type=<ColInfoTypeEnum.default: 1>, column_label='infos', column_align='left', column_width=None), ColInfo(var='Value', type=<ColInfoTypeEnum.default: 1>, column_label='Value', column_align='right', column_width=None), ColInfo(var='DF', type=<ColInfoTypeEnum.default: 1>, column_label='DF', column_align='left', column_width=None), ColInfo(var='DF value', type=<ColInfoTypeEnum.default: 1>, column_label='DF value', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA498990>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Summary Information</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EA508150>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EA509390>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EA5088D0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInf ...

# %% [markdown]
# #### Class Level Informations

# %%
#class level information
print_dt(clf.classes_.infos,rowname="",title=html("<b>Class Level Information</b>"))
# Out:
# GT(_tbl_data=             Frequency  Proportion  Prior Probability
# 0  Mediocre         12      0.3529             0.3529
# 1     Moyen         11      0.3235             0.3235
# 2       Bon         11      0.3235             0.3235, _body=<great_tables._gt_data.Body object at 0x00000181EA50B910>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='left', column_width=None), ColInfo(var='Frequency', type=<ColInfoTypeEnum.default: 1>, column_label='Frequency', column_align='right', column_width=None), ColInfo(var='Proportion', type=<ColInfoTypeEnum.default: 1>, column_label='Proportion', column_align='right', column_width=None), ColInfo(var='Prior Probability', type=<ColInfoTypeEnum.default: 1>, column_label='Prior Probability', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA483650>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Class Level Information</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EA4FFD90>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EA4FF6D0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EA511C10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=Option ...

# %% [markdown]
# ### Sum of Squared Cross Product
#
# #### Within-Class SSCP Matrices

# %%
#Within-Class SSCP Matrices
print("\nWithin-Class SSCP Matrices:")
for k in clf.sscp_.within.keys():
    print("\n{} = {}".format(clf.call_.target,k))
    print(clf.sscp_.within[k].round(3))
# Out:
# Within-Class SSCP Matrices:
#
# Qualite = Mediocre
#              Temperature     Soleil   Chaleur       Pluie
# Temperature    52886.667 -11039.667  2568.667    2497.667
# Soleil        -11039.667  85946.917  1731.583    -657.667
# Chaleur         2568.667   1731.583   436.917    -281.333
# Pluie           2497.667   -657.667  -281.333  120918.667
#
# Qualite = Moyen
#              Temperature     Soleil   Chaleur      Pluie
# Temperature   100090.909  35415.909  5879.455  37930.636
# Soleil         35415.909  51754.909  1882.455   9120.636
# Chaleur         5879.455   1882.455   452.727   2262.818
# Pluie          37930.636   9120.636  2262.818  30234.545
#
# Qualite = Bon
#              Temperature     Soleil   Chaleur    Pluie
# Temperature    84744.545  33908.455  5852.818 -27091.0
# Soleil         33908.455  64490.545  1631.182 -13361.0
# Chaleur         5852.818   1631.182   774.727  -3061.0
# Pluie         -27091.000 -13361.000 -3061.000  27346.0

# %% [markdown]
# #### Pooled Within-Class SSCP Matrix

# %%
#Pooled Within-Class SSCP Matrix
print_dt(clf.sscp_.pooled,rowname="",title=html("<b>Pooled Within-Class SSCP Matrix</b>"))
# Out:
# GT(_tbl_data=                Temperature       Soleil     Chaleur        Pluie
# 0  Temperature  237722.1212   58284.6970  14300.9394   13337.3030
# 1       Soleil   58284.6970  202192.3712   5245.2197   -4898.0303
# 2      Chaleur   14300.9394    5245.2197   1664.3712   -1079.5152
# 3        Pluie   13337.3030   -4898.0303  -1079.5152  178499.2121, _body=<great_tables._gt_data.Body object at 0x00000181EA512DD0>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='left', column_width=None), ColInfo(var='Temperature', type=<ColInfoTypeEnum.default: 1>, column_label='Temperature', column_align='right', column_width=None), ColInfo(var='Soleil', type=<ColInfoTypeEnum.default: 1>, column_label='Soleil', column_align='right', column_width=None), ColInfo(var='Chaleur', type=<ColInfoTypeEnum.default: 1>, column_label='Chaleur', column_align='right', column_width=None), ColInfo(var='Pluie', type=<ColInfoTypeEnum.default: 1>, column_label='Pluie', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA50A950>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Pooled Within-Class SSCP Matrix</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EA512A50>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181C6CD0810>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EA518E50>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), ...

# %% [markdown]
# #### Between-Class SSCP Matrix

# %%
#Between-Class SSCP Matrix
print_dt(clf.sscp_.between,rowname="",title=html("<b>Between SSCP Matrix</b>"))
# Out:
# GT(_tbl_data=                Temperature       Soleil     Chaleur        Pluie
# 0  Temperature  420067.4082  361965.5971  26071.3547 -187772.5383
# 1       Soleil  361965.5971  326909.0700  21811.7215 -175905.8226
# 2      Chaleur   26071.3547   21811.7215   1646.5700  -11039.8378
# 3        Pluie -187772.5383 -175905.8226 -11039.8378   97191.1702, _body=<great_tables._gt_data.Body object at 0x00000181EA51A510>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='left', column_width=None), ColInfo(var='Temperature', type=<ColInfoTypeEnum.default: 1>, column_label='Temperature', column_align='right', column_width=None), ColInfo(var='Soleil', type=<ColInfoTypeEnum.default: 1>, column_label='Soleil', column_align='right', column_width=None), ColInfo(var='Chaleur', type=<ColInfoTypeEnum.default: 1>, column_label='Chaleur', column_align='right', column_width=None), ColInfo(var='Pluie', type=<ColInfoTypeEnum.default: 1>, column_label='Pluie', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA51BFD0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Between SSCP Matrix</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EA51A650>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EA509FD0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EA50B3D0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_bac ...

# %% [markdown]
# #### Total-Sample SSCP Matrix

# %%
#Total-Sample SSCP Matrix
print_dt(clf.sscp_.total,rowname="",title=html("<b>Total-Sample SSCP Matrix</b>"))
# Out:
# GT(_tbl_data=                Temperature       Soleil     Chaleur        Pluie
# 0  Temperature  657789.5294  420250.2941  40372.2941 -174435.2353
# 1       Soleil  420250.2941  529101.4412  27056.9412 -180803.8529
# 2      Chaleur   40372.2941   27056.9412   3310.9412  -12119.3529
# 3        Pluie -174435.2353 -180803.8529 -12119.3529  275690.3824, _body=<great_tables._gt_data.Body object at 0x00000181EC521B90>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='left', column_width=None), ColInfo(var='Temperature', type=<ColInfoTypeEnum.default: 1>, column_label='Temperature', column_align='right', column_width=None), ColInfo(var='Soleil', type=<ColInfoTypeEnum.default: 1>, column_label='Soleil', column_align='right', column_width=None), ColInfo(var='Chaleur', type=<ColInfoTypeEnum.default: 1>, column_label='Chaleur', column_align='right', column_width=None), ColInfo(var='Pluie', type=<ColInfoTypeEnum.default: 1>, column_label='Pluie', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA51B190>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Total-Sample SSCP Matrix</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC521C10>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC521C50>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC521CD0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), headin ...

# %% [markdown]
# ### Covariance matrices
#
# #### Within-Class Covariance Matrices

# %%
#Within-Class Covariance Matrices
print("\nWithin-Class Covariance Matrices:")
for k in clf.cov_.within.keys():
    print("\n{} = {}, DF = {}".format(clf.call_.target,k,clf.classes_.infos.loc[k,"Frequency"]-1))
    print(clf.cov_.within[k].round(3))
# Out:
# Within-Class Covariance Matrices:
#
# Qualite = Mediocre, DF = 11
#              Temperature    Soleil  Chaleur      Pluie
# Temperature     4807.879 -1003.606  233.515    227.061
# Soleil         -1003.606  7813.356  157.417    -59.788
# Chaleur          233.515   157.417   39.720    -25.576
# Pluie            227.061   -59.788  -25.576  10992.606
#
# Qualite = Moyen, DF = 10
#              Temperature    Soleil  Chaleur     Pluie
# Temperature    10009.091  3541.591  587.945  3793.064
# Soleil          3541.591  5175.491  188.245   912.064
# Chaleur          587.945   188.245   45.273   226.282
# Pluie           3793.064   912.064  226.282  3023.455
#
# Qualite = Bon, DF = 10
#              Temperature    Soleil  Chaleur   Pluie
# Temperature     8474.455  3390.845  585.282 -2709.1
# Soleil          3390.845  6449.055  163.118 -1336.1
# Chaleur          585.282   163.118   77.473  -306.1
# Pluie          -2709.100 -1336.100 -306.100  2734.6

# %% [markdown]
# #### Pooled Within-Class Covariance Matrix

# %%
#Pooled Within-Class Covariance Matrix
print_dt(clf.cov_.pooled,rowname="Variables",title=html("<b>Pooled Within-Class Covariance Matrix, DF = {}</b>".format(clf.summary_.infos.iloc[1,3])))
# Out:
# GT(_tbl_data=     Variables  Temperature     Soleil   Chaleur      Pluie
# 0  Temperature    7668.4555  1880.1515  461.3206   430.2356
# 1       Soleil    1880.1515  6522.3346  169.2006  -158.0010
# 2      Chaleur     461.3206   169.2006   53.6894   -34.8231
# 3        Pluie     430.2356  -158.0010  -34.8231  5758.0391, _body=<great_tables._gt_data.Body object at 0x00000181EC533810>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Temperature', type=<ColInfoTypeEnum.default: 1>, column_label='Temperature', column_align='right', column_width=None), ColInfo(var='Soleil', type=<ColInfoTypeEnum.default: 1>, column_label='Soleil', column_align='right', column_width=None), ColInfo(var='Chaleur', type=<ColInfoTypeEnum.default: 1>, column_label='Chaleur', column_align='right', column_width=None), ColInfo(var='Pluie', type=<ColInfoTypeEnum.default: 1>, column_label='Pluie', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA4E8610>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Pooled Within-Class Covariance Matrix, DF = 31</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EA4DC150>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC531ED0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC533A50>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type ...

# %% [markdown]
# #### Between-Class Covariance Matrix

# %%
#Between-Class Covariance Matrix
print_dt(clf.cov_.between,rowname="Variables",title=html("<b>Between-Class Covariance Matrix, DF = {}</b>".format(clf.summary_.infos.iloc[2,3])))
# Out:
# GT(_tbl_data=     Variables  Temperature      Soleil    Chaleur      Pluie
# 0  Temperature   18532.3857  15969.0705  1150.2068 -8284.0826
# 1       Soleil   15969.0705  14422.4590   962.2818 -7760.5510
# 2      Chaleur    1150.2068    962.2818    72.6428  -487.0517
# 3        Pluie   -8284.0826  -7760.5510  -487.0517  4287.8457, _body=<great_tables._gt_data.Body object at 0x00000181EC522C90>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Temperature', type=<ColInfoTypeEnum.default: 1>, column_label='Temperature', column_align='right', column_width=None), ColInfo(var='Soleil', type=<ColInfoTypeEnum.default: 1>, column_label='Soleil', column_align='right', column_width=None), ColInfo(var='Chaleur', type=<ColInfoTypeEnum.default: 1>, column_label='Chaleur', column_align='right', column_width=None), ColInfo(var='Pluie', type=<ColInfoTypeEnum.default: 1>, column_label='Pluie', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC530850>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Between-Class Covariance Matrix, DF = 2</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC538FD0>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC539550>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC538610>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='val ...

# %% [markdown]
# #### Total-Sample Covariance Matrix

# %%
#Total-Sample Covariance Matrix
print_dt(clf.cov_.total,rowname="Variables",title=html("<b>Total-Sample Covariance Matrix, DF = {}</b>".format(clf.summary_.infos.iloc[0,3])))
# Out:
# GT(_tbl_data=     Variables  Temperature      Soleil    Chaleur      Pluie
# 0  Temperature   19933.0160  12734.8574  1223.4029 -5285.9162
# 1       Soleil   12734.8574  16033.3770   819.9073 -5478.9046
# 2      Chaleur    1223.4029    819.9073   100.3316  -367.2531
# 3        Pluie   -5285.9162  -5478.9046  -367.2531  8354.2540, _body=<great_tables._gt_data.Body object at 0x00000181EC53B010>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Temperature', type=<ColInfoTypeEnum.default: 1>, column_label='Temperature', column_align='right', column_width=None), ColInfo(var='Soleil', type=<ColInfoTypeEnum.default: 1>, column_label='Soleil', column_align='right', column_width=None), ColInfo(var='Chaleur', type=<ColInfoTypeEnum.default: 1>, column_label='Chaleur', column_align='right', column_width=None), ColInfo(var='Pluie', type=<ColInfoTypeEnum.default: 1>, column_label='Pluie', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC5392D0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Total-Sample Covariance Matrix, DF = 33</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC540710>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC540410>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC540850>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='val ...

# %% [markdown]
# ### Correlation coefficients
#
# #### Within-Class Correlation Coefficients

# %%
#Within-Class Correlation Coefficients
print("\nWithin-Class Correlation Coefficients/Pr>|r|")
for k in clf.corr_.within.keys():
    print("\n{} = {}".format(clf.call_.target,k))
    print(clf.corr_.within[k].round(3))
# Out:
# Within-Class Correlation Coefficients/Pr>|r|
#
# Qualite = Mediocre
#      Variable1 Variable2      R  t value  DF  Pr>|t|       Conclusion
# 0  Temperature    Soleil -0.164   -0.525  10   0.611  Non-significant
# 1  Temperature   Chaleur  0.534    1.999  10   0.073  Non-significant
# 2  Temperature     Pluie  0.031    0.099  10   0.923  Non-significant
# 3       Soleil   Chaleur  0.283    0.932  10   0.374  Non-significant
# 4       Soleil     Pluie -0.006   -0.020  10   0.984  Non-significant
# 5      Chaleur     Pluie -0.039   -0.122  10   0.905  Non-significant
#
# Qualite = Moyen
#      Variable1 Variable2      R  t value  DF  Pr>|t|       Conclusion
# 0  Temperature    Soleil  0.492    1.696   9   0.124  Non-significant
# 1  Temperature   Chaleur  0.873    5.381   9   0.000      Significant
# 2  Temperature     Pluie  0.690    2.856   9   0.019      Significant
# 3       Soleil   Chaleur  0.389    1.266   9   0.237  Non-significant
# 4       Soleil     Pluie  0.231    0.711   9   0.495  Non-significant
# 5      Chaleur     Pluie  0.612    2.319   9   0.046      Significant
#
# Qualite = Bon
#      Variable1 Variable2      R  t value  DF  Pr>|t|       Conclusion
# 0  Temperature    Soleil  0.459    1.549   9   0.156  Non-significant
# 1  Temperature   Chaleur  0.722    3.134   9   0.012      Significant
# 2  Temperature     Pluie -0.563   -2.042   9   0.071  Non-significant
# 3       Soleil   Chaleur  0.231    0.712   9   0.495  Non-significant
# 4       Soleil     Pluie -0.318   -1.007   9   0.340  Non-significant
# 5      Chaleur     Pluie -0.665   -2.671   9   0.026      Significant

# %% [markdown]
# #### Pooled Within-Class Correlation Coefficients/Pr>|r|

# %%
#Pooled Within-Class Correlation Coefficients/Pr>|r|
print_dt(clf.corr_.pooled,rowname="",title=html("<b>Pooled Within-Class Correlation Coefficients/Pr>|r|</b>"))
# Out:
# GT(_tbl_data=        Variable1 Variable2       R  t value  DF  Pr>|t|       Conclusion
# 0  0  Temperature    Soleil  0.2659   1.5105  30  0.1414  Non-significant
# 1  1  Temperature   Chaleur  0.7190   5.6656  30  0.0000      Significant
# 2  2  Temperature     Pluie  0.0647   0.3554  30  0.7248  Non-significant
# 3  3       Soleil   Chaleur  0.2859   1.6343  30  0.1126  Non-significant
# 4  4       Soleil     Pluie -0.0258  -0.1413  30  0.8886  Non-significant
# 5  5      Chaleur     Pluie -0.0626  -0.3437  30  0.7335  Non-significant, _body=<great_tables._gt_data.Body object at 0x00000181EA509DD0>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='Variable1', type=<ColInfoTypeEnum.default: 1>, column_label='Variable1', column_align='left', column_width=None), ColInfo(var='Variable2', type=<ColInfoTypeEnum.default: 1>, column_label='Variable2', column_align='left', column_width=None), ColInfo(var='R', type=<ColInfoTypeEnum.default: 1>, column_label='R', column_align='right', column_width=None), ColInfo(var='t value', type=<ColInfoTypeEnum.default: 1>, column_label='t value', column_align='right', column_width=None), ColInfo(var='DF', type=<ColInfoTypeEnum.default: 1>, column_label='DF', column_align='right', column_width=None), ColInfo(var='Pr>|t|', type=<ColInfoTypeEnum.default: 1>, column_label='Pr>|t|', column_align='right', column_width=None), ColInfo(var='Conclusion', type=<ColInfoTypeEnum.default: 1>, column_label='Conclusion', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC53BF50>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Pooled Within-Class Correlation Coefficients/Pr>|r|</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC54A250>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC54A4D0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC54A790>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value=' ...

# %% [markdown]
# #### Between-Class Correlation Coefficients/Pr>|r|

# %%
#Between-Class Correlation Coefficients/Pr>|r|
print_dt(clf.corr_.between,rowname="",title=html("<b>Between-Class Correlation Coefficients/Pr>|r|</b>"))
# Out:
# GT(_tbl_data=        Variable1 Variable2       R  t value  DF  Pr>|t|       Conclusion
# 0  0  Temperature    Soleil  0.9768   4.5586   1  0.1375  Non-significant
# 1  1  Temperature   Chaleur  0.9913   7.5404   1  0.0839  Non-significant
# 2  2  Temperature     Pluie -0.9293  -2.5163   1  0.2408  Non-significant
# 3  3       Soleil   Chaleur  0.9401   2.7584   1  0.2214  Non-significant
# 4  4       Soleil     Pluie -0.9869  -6.1065   1  0.1033  Non-significant
# 5  5      Chaleur     Pluie -0.8727  -1.7873   1  0.3247  Non-significant, _body=<great_tables._gt_data.Body object at 0x00000181EC54AD50>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='Variable1', type=<ColInfoTypeEnum.default: 1>, column_label='Variable1', column_align='left', column_width=None), ColInfo(var='Variable2', type=<ColInfoTypeEnum.default: 1>, column_label='Variable2', column_align='left', column_width=None), ColInfo(var='R', type=<ColInfoTypeEnum.default: 1>, column_label='R', column_align='right', column_width=None), ColInfo(var='t value', type=<ColInfoTypeEnum.default: 1>, column_label='t value', column_align='right', column_width=None), ColInfo(var='DF', type=<ColInfoTypeEnum.default: 1>, column_label='DF', column_align='right', column_width=None), ColInfo(var='Pr>|t|', type=<ColInfoTypeEnum.default: 1>, column_label='Pr>|t|', column_align='right', column_width=None), ColInfo(var='Conclusion', type=<ColInfoTypeEnum.default: 1>, column_label='Conclusion', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA429F50>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Between-Class Correlation Coefficients/Pr>|r|</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC54D410>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC54CE50>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC54D290>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), ...

# %% [markdown]
# #### Total-Sample Correlation Coefficients/Pr>|r|

# %%
#Total-Sample Correlation Coefficients/Pr>|r|
print_dt(clf.corr_.total,rowname="",title=html("<>Total-Sample Correlation Coefficients/Pr>|r|</b>"))
# Out:
# GT(_tbl_data=        Variable1 Variable2       R  t value  DF  Pr>|t|   Conclusion
# 0  0  Temperature    Soleil  0.7124   5.7417  32  0.0000  Significant
# 1  1  Temperature   Chaleur  0.8651   9.7561  32  0.0000  Significant
# 2  2  Temperature     Pluie -0.4096  -2.5400  32  0.0161  Significant
# 3  3       Soleil   Chaleur  0.6464   4.7930  32  0.0000  Significant
# 4  4       Soleil     Pluie -0.4734  -3.0402  32  0.0047  Significant
# 5  5      Chaleur     Pluie -0.4011  -2.4772  32  0.0187  Significant, _body=<great_tables._gt_data.Body object at 0x00000181EC54DF50>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='Variable1', type=<ColInfoTypeEnum.default: 1>, column_label='Variable1', column_align='left', column_width=None), ColInfo(var='Variable2', type=<ColInfoTypeEnum.default: 1>, column_label='Variable2', column_align='left', column_width=None), ColInfo(var='R', type=<ColInfoTypeEnum.default: 1>, column_label='R', column_align='right', column_width=None), ColInfo(var='t value', type=<ColInfoTypeEnum.default: 1>, column_label='t value', column_align='right', column_width=None), ColInfo(var='DF', type=<ColInfoTypeEnum.default: 1>, column_label='DF', column_align='right', column_width=None), ColInfo(var='Pr>|t|', type=<ColInfoTypeEnum.default: 1>, column_label='Pr>|t|', column_align='right', column_width=None), ColInfo(var='Conclusion', type=<ColInfoTypeEnum.default: 1>, column_label='Conclusion', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA427250>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<>Total-Sample Correlation Coefficients/Pr>|r|</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC561A10>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC560ED0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC561950>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table ...

# %% [markdown]
# ### Simple Statistics
#
# #### Total statistics

# %%
#total statistics
print_dt(clf.summary_.total,rowname="Variable",title=html("<b>Total statistic</b>"))
# Out:
# GT(_tbl_data=      Variable  count       mean       std     min      25%     50%      75%  \
# 0  Temperature     34  3157.8824  141.1843  2904.0  3045.25  3140.5  3250.75
# 1       Soleil     34  1247.3235  126.6230   966.0  1177.75  1253.0  1330.50
# 2      Chaleur     34    18.8235   10.0166     4.0    11.25    16.5    24.75
# 3        Pluie     34   360.4412   91.4016   225.0   302.25   342.5   408.75
#
#       max
# 0  3478.0
# 1  1508.0
# 2    43.0
# 3   677.0  , _body=<great_tables._gt_data.Body object at 0x00000181EC56A090>, _boxhead=Boxhead([ColInfo(var='Variable', type=<ColInfoTypeEnum.default: 1>, column_label='Variable', column_align='left', column_width=None), ColInfo(var='count', type=<ColInfoTypeEnum.default: 1>, column_label='count', column_align='right', column_width=None), ColInfo(var='mean', type=<ColInfoTypeEnum.default: 1>, column_label='mean', column_align='right', column_width=None), ColInfo(var='std', type=<ColInfoTypeEnum.default: 1>, column_label='std', column_align='right', column_width=None), ColInfo(var='min', type=<ColInfoTypeEnum.default: 1>, column_label='min', column_align='right', column_width=None), ColInfo(var='25%', type=<ColInfoTypeEnum.default: 1>, column_label='25%', column_align='right', column_width=None), ColInfo(var='50%', type=<ColInfoTypeEnum.default: 1>, column_label='50%', column_align='right', column_width=None), ColInfo(var='75%', type=<ColInfoTypeEnum.default: 1>, column_label='75%', column_align='right', column_width=None), ColInfo(var='max', type=<ColInfoTypeEnum.default: 1>, column_label='max', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC54FD90>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Total statistic</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC569590>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC5695D0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC56A050>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px' ...

# %% [markdown]
# #### Within-class statistics

# %%
#whitin-class statistics
print("\nwhitin-class statistics")
for k in clf.summary_.within.keys():
    print("\n{}".format(k))
    print(clf.summary_.within[k].round(3))
# Out:
# whitin-class statistics
#
# Mediocre
#              count      mean      std     min      25%     50%      75%  \
# Temperature     12  3037.333   69.339  2904.0  2999.50  3040.5  3080.75
# Soleil          12  1126.417   88.393   966.0  1089.75  1167.5  1190.50
# Chaleur         12    12.083    6.302     4.0     8.25    12.5    14.00
# Pluie           12   430.333  104.846   311.0   346.25   429.0   472.25
#
#                 max
# Temperature  3182.0
# Soleil       1210.0
# Chaleur        28.0
# Pluie         677.0
#
# Moyen
#              count      mean      std     min     25%     50%     75%     max
# Temperature     11  3140.909  100.045  3019.0  3062.5  3126.0  3219.5  3318.0
# Soleil          11  1262.909   71.941  1133.0  1215.5  1285.0  1319.5  1361.0
# Chaleur         11    16.455    6.729     9.0    11.0    16.0    20.0    29.0
# Pluie           11   339.636   54.986   261.0   302.5   339.0   377.0   427.0
#
# Bon
#              count      mean     std     min     25%     50%     75%     max
# Temperature     11  3306.364  92.057  3198.0  3246.0  3270.0  3339.0  3478.0
# Soleil          11  1363.636  80.306  1258.0  1297.0  1366.0  1411.5  1508.0
# Chaleur         11    28.545   8.802    19.0    22.5    25.0    35.5    43.0
# Pluie           11   305.000  52.293   225.0   270.5   294.0   346.5   382.0

# %% [markdown]
# ### Class means

# %% [markdown]
# #### Total-sample class means

# %%
#total-sample class means
print_dt(clf.classes_.center.T,rowname="{}".format(clf.call_.target),title=html("<b>Total-sample class means</b>"))
# Out:
# GT(_tbl_data=       Qualite   Mediocre      Moyen        Bon
# 0  Temperature  3037.3333  3140.9091  3306.3636
# 1       Soleil  1126.4167  1262.9091  1363.6364
# 2      Chaleur    12.0833    16.4545    28.5455
# 3        Pluie   430.3333   339.6364   305.0000, _body=<great_tables._gt_data.Body object at 0x00000181EC5662D0>, _boxhead=Boxhead([ColInfo(var='Qualite', type=<ColInfoTypeEnum.default: 1>, column_label='Qualite', column_align='left', column_width=None), ColInfo(var='Mediocre', type=<ColInfoTypeEnum.default: 1>, column_label='Mediocre', column_align='right', column_width=None), ColInfo(var='Moyen', type=<ColInfoTypeEnum.default: 1>, column_label='Moyen', column_align='right', column_width=None), ColInfo(var='Bon', type=<ColInfoTypeEnum.default: 1>, column_label='Bon', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC56A650>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Total-sample class means</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC565050>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC565210>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC565B10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='head ...

# %% [markdown]
# #### Total-Sample Standardized Class Means

# %%
#Total-Sample Standardized Class Means
print_dt(clf.classes_.total,rowname="{}".format(clf.call_.target),title=html("<b>Total-Sample Standardized Class Means</b>"))
# Out:
# GT(_tbl_data=       Qualite  Mediocre   Moyen     Bon
# 0  Temperature   -0.8538 -0.1202  1.0517
# 1       Soleil   -0.9549  0.1231  0.9186
# 2      Chaleur   -0.6729 -0.2365  0.9706
# 3        Pluie    0.7647 -0.2276 -0.6066, _body=<great_tables._gt_data.Body object at 0x00000181EC575610>, _boxhead=Boxhead([ColInfo(var='Qualite', type=<ColInfoTypeEnum.default: 1>, column_label='Qualite', column_align='left', column_width=None), ColInfo(var='Mediocre', type=<ColInfoTypeEnum.default: 1>, column_label='Mediocre', column_align='right', column_width=None), ColInfo(var='Moyen', type=<ColInfoTypeEnum.default: 1>, column_label='Moyen', column_align='right', column_width=None), ColInfo(var='Bon', type=<ColInfoTypeEnum.default: 1>, column_label='Bon', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC564E10>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Total-Sample Standardized Class Means</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC574190>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC575910>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC574090>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category ...

# %% [markdown]
# #### Pooled-Within Class Standardized Class Means

# %%
print_dt(clf.classes_.pooled,rowname="{}".format(clf.call_.target),title=html("<b>Pooled-Within Class Standardized Class Means</b>"))
# Out:
# GT(_tbl_data=       Qualite  Mediocre   Moyen     Bon
# 0  Temperature   -1.3766 -0.1938  1.6956
# 1       Soleil   -1.4971  0.1930  1.4402
# 2      Chaleur   -0.9199 -0.3233  1.3268
# 3        Pluie    0.9211 -0.2742 -0.7306, _body=<great_tables._gt_data.Body object at 0x00000181EC58C050>, _boxhead=Boxhead([ColInfo(var='Qualite', type=<ColInfoTypeEnum.default: 1>, column_label='Qualite', column_align='left', column_width=None), ColInfo(var='Mediocre', type=<ColInfoTypeEnum.default: 1>, column_label='Mediocre', column_align='right', column_width=None), ColInfo(var='Moyen', type=<ColInfoTypeEnum.default: 1>, column_label='Moyen', column_align='right', column_width=None), ColInfo(var='Bon', type=<ColInfoTypeEnum.default: 1>, column_label='Bon', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA4DD350>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Pooled-Within Class Standardized Class Means</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC58C110>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC58C090>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC58C390>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, c ...

# %% [markdown]
# #### Squared Distances to Qualite

# %%
#squared distances to Qualite
print_dt(clf.classes_.mahal.round(3),rowname="{}".format(clf.call_.target),title=html("<b>Squared Distance to {}</b>".format(clf.call_.target)))
# Out:
# GT(_tbl_data=    Qualite  Mediocre  Moyen     Bon
# 0  Mediocre     0.000  5.492  17.653
# 1     Moyen     5.492  0.000   4.519
# 2       Bon    17.653  4.519   0.000, _body=<great_tables._gt_data.Body object at 0x00000181EC591510>, _boxhead=Boxhead([ColInfo(var='Qualite', type=<ColInfoTypeEnum.default: 1>, column_label='Qualite', column_align='left', column_width=None), ColInfo(var='Mediocre', type=<ColInfoTypeEnum.default: 1>, column_label='Mediocre', column_align='right', column_width=None), ColInfo(var='Moyen', type=<ColInfoTypeEnum.default: 1>, column_label='Moyen', column_align='right', column_width=None), ColInfo(var='Bon', type=<ColInfoTypeEnum.default: 1>, column_label='Bon', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC53AD10>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Squared Distance to Qualite</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC591750>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC591210>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC5901D0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', ty ...

# %% [markdown]
# #### Generalized Squared distance to Qualite

# %%
#generalized squared distance to Qualite
print_dt(clf.classes_.gen.round(3),rowname="{}".format(clf.call_.target),title=html("<b>Generalized Distance to {}</b>".format(clf.call_.target)))
# Out:
# GT(_tbl_data=    Qualite  Mediocre  Moyen     Bon
# 0  Mediocre     2.083  7.749  19.910
# 1     Moyen     7.575  2.257   6.776
# 2       Bon    19.736  6.776   2.257, _body=<great_tables._gt_data.Body object at 0x00000181EC58C150>, _boxhead=Boxhead([ColInfo(var='Qualite', type=<ColInfoTypeEnum.default: 1>, column_label='Qualite', column_align='left', column_width=None), ColInfo(var='Mediocre', type=<ColInfoTypeEnum.default: 1>, column_label='Mediocre', column_align='right', column_width=None), ColInfo(var='Moyen', type=<ColInfoTypeEnum.default: 1>, column_label='Moyen', column_align='right', column_width=None), ColInfo(var='Bon', type=<ColInfoTypeEnum.default: 1>, column_label='Bon', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA4B8650>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Generalized Distance to Qualite</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC58EB90>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC58D9D0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC58E610>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading' ...

# %% [markdown]
# ### Statistics
#
# #### Univariate Test Statistics

# %%
#Univariate Test Statistics
print_dt(clf.statistics_.anova,rowname="Variables",title=html("<b>Univariate Test Statistics</b>"))
# Out:
# GT(_tbl_data=     Variables  Total Std. Dev.  Pooled Std. Dev.  Between Std. Dev.  \
# 0  Temperature         141.1843           87.5697           136.1337
# 1       Soleil         126.6230           80.7610           120.0935
# 2      Chaleur          10.0166            7.3273             8.5231
# 3        Pluie          91.4016           75.8817            65.4816
#
#      Within SS   Between SS  R-Square  R-Square/(1-RSq)  F Value  Num DF  \
# 0  237722.1212  420067.4082    0.6386            1.7671  27.3893       2
# 1  202192.3712  326909.0700    0.6179            1.6168  25.0607       2
# 2    1664.3712    1646.5700    0.4973            0.9893  15.3342       2
# 3  178499.2121   97191.1702    0.3525            0.5445   8.4396       2
#
#    Den DF    Pr>F
# 0      31  0.0000
# 1      31  0.0000
# 2      31  0.0000
# 3      31  0.0012  , _body=<great_tables._gt_data.Body object at 0x00000181EC59C850>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Total Std. Dev.', type=<ColInfoTypeEnum.default: 1>, column_label='Total Std. Dev.', column_align='right', column_width=None), ColInfo(var='Pooled Std. Dev.', type=<ColInfoTypeEnum.default: 1>, column_label='Pooled Std. Dev.', column_align='right', column_width=None), ColInfo(var='Between Std. Dev.', type=<ColInfoTypeEnum.default: 1>, column_label='Between Std. Dev.', column_align='right', column_width=None), ColInfo(var='Within SS', type=<ColInfoTypeEnum.default: 1>, column_label='Within SS', column_align='right', column_width=None), ColInfo(var='Between SS', type=<ColInfoTypeEnum.default: 1>, column_label='Between SS', column_align='right', column_width=None), ColInfo(var='R-Square', type=<ColInfoTypeEnum.default: 1>, column_label='R-Square', column_align='right', column_width=None), ColInfo(var='R-Square/(1-RSq)', type=<ColInfoTypeEnum.default: 1>, column_label='R-Square/(1-RSq)', column_align='right', column_width=None), ColInfo(var='F Value', type=<ColInfoTypeEnum.default: 1>, column_label='F Value', column_align='right', column_width=None), ColInfo(var='Num DF', type=<ColInfoTypeEnum.default: 1>, column_label='Num DF', column_align='right', column_width=None), ColInfo(var='Den DF', type=<ColInfoTypeEnum.default: 1>, column_label='Den DF', column_align='right', column_width=None), ColInfo(var='Pr>F', type=<ColInfoTypeEnum.default: 1>, column_label='Pr>F', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC591950>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Univariate Test Statistics</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC59C910>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC59C950>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC59C990>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=Tr ...

# %% [markdown]
# #### Average R-square

# %%
#Average R-square
print_dt(clf.statistics_.average_rsq,rowname="",title=html("<b>Average R-square</b>"))
# Out:
# GT(_tbl_data=                     Unweighted  Weighted by Variance
# 0  Average R-Square      0.5266                 0.577, _body=<great_tables._gt_data.Body object at 0x00000181EC59D790>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='left', column_width=None), ColInfo(var='Unweighted', type=<ColInfoTypeEnum.default: 1>, column_label='Unweighted', column_align='right', column_width=None), ColInfo(var='Weighted by Variance', type=<ColInfoTypeEnum.default: 1>, column_label='Weighted by Variance', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC592ED0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Average R-square</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC59E210>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC59E350>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC59D810>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='head ...

# %% [markdown]
# #### Multivariate Statistics and F Approximations

# %%
#Multivariate Statistics and F Approximations
print_dt(clf.statistics_.manova,rowname="Statistics",title=html("<b>Multivariate Statistics and F Approximations</b>"))
# Out:
# GT(_tbl_data=               Statistics     Value Num DF Den DF    F Value   Pr > F
# 0           Wilks' lambda  0.205263      8   56.0   8.450507      0.0
# 1          Pillai's trace  0.888001    8.0   58.0   5.789584  0.00002
# 2  Hotelling-Lawley trace  3.417435      8  37.75  11.728014      0.0
# 3     Roy's greatest root   3.27886      4     29  23.771739      0.0, _body=<great_tables._gt_data.Body object at 0x00000181EC5B62D0>, _boxhead=Boxhead([ColInfo(var='Statistics', type=<ColInfoTypeEnum.default: 1>, column_label='Statistics', column_align='left', column_width=None), ColInfo(var='Value', type=<ColInfoTypeEnum.default: 1>, column_label='Value', column_align='right', column_width=None), ColInfo(var='Num DF', type=<ColInfoTypeEnum.default: 1>, column_label='Num DF', column_align='right', column_width=None), ColInfo(var='Den DF', type=<ColInfoTypeEnum.default: 1>, column_label='Den DF', column_align='right', column_width=None), ColInfo(var='F Value', type=<ColInfoTypeEnum.default: 1>, column_label='F Value', column_align='right', column_width=None), ColInfo(var='Pr > F', type=<ColInfoTypeEnum.default: 1>, column_label='Pr > F', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC59FA10>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Multivariate Statistics and F Approximations</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC5B6E50>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC5B6750>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC5B43D0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(s ...

# %% [markdown]
# ### Canonical Informations
#
# #### Canonical correlations

# %%
#canonical correlations
print_dt(clf.cancorr_,rowname="",title=html("<b>Canonical correlations</b>"))
# Out:
# GT(_tbl_data=      Canonical Correlation  Squared Canonical Correlation  Likelihood Ratio  \
# 0  0                 0.8754                         0.7663            0.2053
# 1  1                 0.3489                         0.1217            0.8783
#
#    Approximate F value  Num DF  Den DF    Pr>F  Chi-Square  DF  Pr>Chi2
# 0               8.4505       8      56  0.0000     46.7122   8   0.0000
# 1               1.3395       3      29  0.2808      3.8284   3   0.2806  , _body=<great_tables._gt_data.Body object at 0x00000181EC5BDD50>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='Canonical Correlation', type=<ColInfoTypeEnum.default: 1>, column_label='Canonical Correlation', column_align='right', column_width=None), ColInfo(var='Squared Canonical Correlation', type=<ColInfoTypeEnum.default: 1>, column_label='Squared Canonical Correlation', column_align='right', column_width=None), ColInfo(var='Likelihood Ratio', type=<ColInfoTypeEnum.default: 1>, column_label='Likelihood Ratio', column_align='right', column_width=None), ColInfo(var='Approximate F value', type=<ColInfoTypeEnum.default: 1>, column_label='Approximate F value', column_align='right', column_width=None), ColInfo(var='Num DF', type=<ColInfoTypeEnum.default: 1>, column_label='Num DF', column_align='right', column_width=None), ColInfo(var='Den DF', type=<ColInfoTypeEnum.default: 1>, column_label='Den DF', column_align='right', column_width=None), ColInfo(var='Pr>F', type=<ColInfoTypeEnum.default: 1>, column_label='Pr>F', column_align='right', column_width=None), ColInfo(var='Chi-Square', type=<ColInfoTypeEnum.default: 1>, column_label='Chi-Square', column_align='right', column_width=None), ColInfo(var='DF', type=<ColInfoTypeEnum.default: 1>, column_label='DF', column_align='right', column_width=None), ColInfo(var='Pr>Chi2', type=<ColInfoTypeEnum.default: 1>, column_label='Pr>Chi2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC59EF10>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Canonical correlations</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC5BFE10>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC5BE8D0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC5BFF50>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_r ...

# %% [markdown]
# #### Canonical eigenvalues

# %%
print_dt(clf.eig_,rowname="Dimension",title=html("<b>Canonical eigenvalues</b>"))
# Out:
# GT(_tbl_data=  Dimension  Eigenvalue  Difference  Proportion  Cumulative
# 0      Can1      3.2789      3.1403     95.9451     95.9451
# 1      Can2      0.1386         NaN      4.0549    100.0000, _body=<great_tables._gt_data.Body object at 0x00000181EC5C0C10>, _boxhead=Boxhead([ColInfo(var='Dimension', type=<ColInfoTypeEnum.default: 1>, column_label='Dimension', column_align='left', column_width=None), ColInfo(var='Eigenvalue', type=<ColInfoTypeEnum.default: 1>, column_label='Eigenvalue', column_align='right', column_width=None), ColInfo(var='Difference', type=<ColInfoTypeEnum.default: 1>, column_label='Difference', column_align='right', column_width=None), ColInfo(var='Proportion', type=<ColInfoTypeEnum.default: 1>, column_label='Proportion', column_align='right', column_width=None), ColInfo(var='Cumulative', type=<ColInfoTypeEnum.default: 1>, column_label='Cumulative', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC56AE10>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Canonical eigenvalues</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC5C0F50>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC5C0CD0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC5C1750>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='v ...

# %% [markdown]
# ### Canoncial structure
#
# #### Total canonical structure

# %%
#total canonical structure
print_dt(clf.var_.total,rowname="Variables",title=html("<b>Total Canonical Structure</b>"))
# Out:
# GT(_tbl_data=     Variables    Can1    Can2
# 0  Temperature  0.9006  0.3748
# 1       Soleil  0.8967 -0.1162
# 2      Chaleur  0.7705  0.5900
# 3        Pluie -0.6628  0.3613, _body=<great_tables._gt_data.Body object at 0x00000181EC5C3050>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Can1', type=<ColInfoTypeEnum.default: 1>, column_label='Can1', column_align='right', column_width=None), ColInfo(var='Can2', type=<ColInfoTypeEnum.default: 1>, column_label='Can2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC5C1AD0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Total Canonical Structure</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC565710>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC54D7D0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC54D610>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_ ...

# %% [markdown]
# #### Between canonical structure

# %%
#between canonical structure
print_dt(clf.var_.between,rowname="Variables",title=html("<b>Between Canonical Structure</b>"))
# Out:
# GT(_tbl_data=     Variables    Can1    Can2
# 0  Temperature  0.9865  0.1636
# 1       Soleil  0.9987 -0.0516
# 2      Chaleur  0.9565  0.2919
# 3        Pluie -0.9772  0.2123, _body=<great_tables._gt_data.Body object at 0x00000181EC5D8C90>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Can1', type=<ColInfoTypeEnum.default: 1>, column_label='Can1', column_align='right', column_width=None), ColInfo(var='Can2', type=<ColInfoTypeEnum.default: 1>, column_label='Can2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC5D6C10>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Between Canonical Structure</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC5D8F10>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC5D9590>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC5D9510>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), headin ...

# %% [markdown]
# #### Pooled within-class canonical structure

# %%
#Pooled within-class canonical structure
print_dt(clf.var_.pooled,rowname="Variable",title=html("<b>Pooled Within Canonical Structure</b>"))
# Out:
# GT(_tbl_data=      Variable    Can1    Can2
# 0  Temperature  0.7242  0.5843
# 1       Soleil  0.7013 -0.1761
# 2      Chaleur  0.5254  0.7799
# 3        Pluie -0.3982  0.4208, _body=<great_tables._gt_data.Body object at 0x00000181EC5D4E10>, _boxhead=Boxhead([ColInfo(var='Variable', type=<ColInfoTypeEnum.default: 1>, column_label='Variable', column_align='left', column_width=None), ColInfo(var='Can1', type=<ColInfoTypeEnum.default: 1>, column_label='Can1', column_align='right', column_width=None), ColInfo(var='Can2', type=<ColInfoTypeEnum.default: 1>, column_label='Can2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC5D87D0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Pooled Within Canonical Structure</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC5D7550>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC5D7510>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC5D6890>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), he ...

# %% [markdown]
# ### Canonical coefficients
#
# #### Raw canonical coefficients

# %%
#raw canonical correlations
print_dt(clf.cancoef_.raw,rowname="",title=html("<b>Canonical coefficients</b>"))
# Out:
# GT(_tbl_data=                   Can1    Can2
# 0     Constant -32.8763  2.1653
# 1  Temperature   0.0086 -0.0000
# 2       Soleil   0.0068 -0.0053
# 3      Chaleur  -0.0271  0.1276
# 4        Pluie  -0.0059  0.0062, _body=<great_tables._gt_data.Body object at 0x00000181EC5E5050>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='left', column_width=None), ColInfo(var='Can1', type=<ColInfoTypeEnum.default: 1>, column_label='Can1', column_align='right', column_width=None), ColInfo(var='Can2', type=<ColInfoTypeEnum.default: 1>, column_label='Can2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC59CE90>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Canonical coefficients</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC5E5B50>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC5E69D0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC5E6F50>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=Op ...

# %% [markdown]
# #### Total Sample Standardized Canonical Coefficients

# %%
#Total Sample Standardized Canonical Coefficients
print_dt(clf.cancoef_.total,rowname="",title=html("<b>Total Sample Standardized Canonical Coefficients</b>"))
# Out:
# GT(_tbl_data=                  Can1    Can2
# 0  Temperature  1.2094 -0.0065
# 1       Soleil  0.8577 -0.6748
# 2      Chaleur -0.2710  1.2785
# 3        Pluie -0.5361  0.5644, _body=<great_tables._gt_data.Body object at 0x00000181EC5E9610>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='left', column_width=None), ColInfo(var='Can1', type=<ColInfoTypeEnum.default: 1>, column_label='Can1', column_align='right', column_width=None), ColInfo(var='Can2', type=<ColInfoTypeEnum.default: 1>, column_label='Can2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC5E5810>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Total Sample Standardized Canonical Coefficients</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC5E9A50>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC5E8E50>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC5E9990>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), hea ...

# %% [markdown]
# #### Pooled Within class Standardized Canonical Coefficients

# %%
#Pooled Within class Standardized Canonical Coefficients
print_dt(clf.cancoef_.pooled,rowname="",title=html("<b>Pooled Within class Standardized Canonical Coefficients</b>"))
# Out:
# GT(_tbl_data=                  Can1    Can2
# 0  Temperature  0.7501 -0.0041
# 1       Soleil  0.5471 -0.4304
# 2      Chaleur -0.1982  0.9352
# 3        Pluie -0.4451  0.4685, _body=<great_tables._gt_data.Body object at 0x00000181EA4EBA50>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='left', column_width=None), ColInfo(var='Can1', type=<ColInfoTypeEnum.default: 1>, column_label='Can1', column_align='right', column_width=None), ColInfo(var='Can2', type=<ColInfoTypeEnum.default: 1>, column_label='Can2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC5EA690>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Pooled Within class Standardized Canonical Coefficients</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC5D6750>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC5D6650>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC5D4510>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125% ...

# %% [markdown]
# ### Class Means on Canonical Variables

# %%
#Class Means on Canonical Variables
print_dt(clf.classes_.coord,rowname="{}".format(clf.call_.target),title=html("<b>Class Means on Canonical Variables</b>"))
# Out:
# GT(_tbl_data=    Qualite    Can1    Can2
# 0  Mediocre -2.0792  0.2212
# 1     Moyen  0.1463 -0.5131
# 2       Bon  2.1220  0.2718, _body=<great_tables._gt_data.Body object at 0x00000181EC5F0C50>, _boxhead=Boxhead([ColInfo(var='Qualite', type=<ColInfoTypeEnum.default: 1>, column_label='Qualite', column_align='left', column_width=None), ColInfo(var='Can1', type=<ColInfoTypeEnum.default: 1>, column_label='Can1', column_align='right', column_width=None), ColInfo(var='Can2', type=<ColInfoTypeEnum.default: 1>, column_label='Can2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC5E9F10>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Class Means on Canonical Variables</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC5F1690>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC5F1610>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC5F18D0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), headin ...

# %% [markdown]
# ### `summary`

# %%
from discrimintools import summaryCANDISC

# %% [markdown]
# #### Simple summary

# %%
#simple summary
summaryCANDISC(clf)
# Out:
#                      Canonical Discriminant Analysis - Results
#
# Summary Information:
#                infos  Value                  DF  DF value
# 0  Total Sample Size     34            DF Total        33
# 1          Variables      4   DF Within Classes        31
# 2            Classes      3  DF Between Classes         2
#
# Class Level Information:
#           Frequency  Proportion  Prior Probability
# Mediocre         12      0.3529             0.3529
# Moyen            11      0.3235             0.3235
# Bon              11      0.3235             0.3235
#
# Total-Sample Class Means:
#               Mediocre      Moyen        Bon
# Temperature  3037.3333  3140.9091  3306.3636
# Soleil       1126.4167  1262.9091  1363.6364
# Chaleur        12.0833    16.4545    28.5455
# Pluie         430.3333   339.6364   305.0000
#
# Importance of components:
#       Eigenvalue  Difference  Proportion  Cumulative
# Can1      3.2789      3.1403     95.9451     95.9451
# Can2      0.1386         NaN      4.0549    100.0000
#
# Raw Canonical and Classification Functions Coefficients:
#                 Can1    Can2  Mediocre   Moyen      Bon
# Constant    -32.8763  2.1653   65.6093 -7.1918 -72.5905
# Temperature   0.0086 -0.0000   -0.0178  0.0013   0.0182
# Soleil        0.0068 -0.0053   -0.0153  0.0037   0.0129
# Chaleur      -0.0271  0.1276    0.0845 -0.0694  -0.0227
# Pluie        -0.0059  0.0062    0.0136 -0.0040  -0.0108

# %% [markdown]
# #### Detailed summary

# %%
#detailed summary
summaryCANDISC(clf,detailed=True)
# Out:
#                      Canonical Discriminant Analysis - Results
#
# Summary Information:
#                infos  Value                  DF  DF value
# 0  Total Sample Size     34            DF Total        33
# 1          Variables      4   DF Within Classes        31
# 2            Classes      3  DF Between Classes         2
#
# Class Level Information:
#           Frequency  Proportion  Prior Probability
# Mediocre         12      0.3529             0.3529
# Moyen            11      0.3235             0.3235
# Bon              11      0.3235             0.3235
#
# Total-Sample Class Means:
#               Mediocre      Moyen        Bon
# Temperature  3037.3333  3140.9091  3306.3636
# Soleil       1126.4167  1262.9091  1363.6364
# Chaleur        12.0833    16.4545    28.5455
# Pluie         430.3333   339.6364   305.0000
#
# Importance of components:
#       Eigenvalue  Difference  Proportion  Cumulative
# Can1      3.2789      3.1403     95.9451     95.9451
# Can2      0.1386         NaN      4.0549    100.0000
#
# Raw Canonical and Classification Functions Coefficients:
#                 Can1    Can2  Mediocre   Moyen      Bon
# Constant    -32.8763  2.1653   65.6093 -7.1918 -72.5905
# Temperature   0.0086 -0.0000   -0.0178  0.0013   0.0182
# Soleil        0.0068 -0.0053   -0.0153  0.0037   0.0129
# Chaleur      -0.0271  0.1276    0.0845 -0.0694  -0.0227
# Pluie        -0.0059  0.0062    0.0136 -0.0040  -0.0108
#
# Test of H0: The canonical correlations in the current row and all that follow are zero
#    Canonical Correlation  Squared Canonical Correlation  Likelihood Ratio  \
# 0                 0.8754                         0.7663            0.2053
# 1                 0.3489                         0.1217            0.8783
#
#    Approximate F value  Num DF  Den DF    Pr>F  Chi-Square  DF  Pr>Chi2
# 0               8.4505       8      56  0.0000     46.7122   8   0.0000
# 1               1.3395       3      29  0.2808      3.8284   3   0.2806
#
# Classification Summary for Calibration Data:
#
# Observation Profile:
#                         Read  Used
# Number of Observations    34    34
#
# Number of Observations Classified into Qualite:
# prediction  Mediocre  Moyen  Bon  Total
# Qualite
# Mediocre          10      2    0     12
# Moyen              1      8    2     11
# Bon                0      2    9     11
# Total             11     12   11     34
#
# Percent Classified into Qualite:
# prediction  Mediocre    Moyen      Bon  Total
# Qualite
# Mediocre     83.3333  16.6667   0.0000  100.0
# Moyen         9.0909  72.7273  18.1818  100.0
# Bon           0.0000  18.1818  81.8182  100.0
# Total        32.3529  35.2941  32.3529  100.0
# Priors        0.3529   0.3235   0.3235    NaN
#
# Error Count Estimates for Qualite:
#         Mediocre   Moyen     Bon   Total
# Rate      0.1667  0.2727  0.1818  0.2059
# Priors    0.3529  0.3235  0.3235     NaN
#
# Classification Report for Qualite:
#               precision  recall  f1-score  support
# Mediocre         0.9091  0.8333    0.8696  12.0000
# Moyen            0.6667  0.7273    0.6957  11.0000
# Bon              0.8182  0.8182    0.8182  11.0000
# accuracy         0.7941  0.7941    0.7941   0.7941
# macro avg        0.7980  0.7929    0.7945  34.0000
# weighted avg     0.8012  0.7941    0.7967  34.0000

# %% [markdown]
# #### Markdown format

# %%
#markdown format
summaryCANDISC(clf,detailed=True,to_markdown=True)
# Out:
#                      Canonical Discriminant Analysis - Results
#
# Summary Information:
# |    | infos             |   Value | DF                 |   DF value |
# |----|-------------------|---------|--------------------|------------|
# |  0 | Total Sample Size |      34 | DF Total           |         33 |
# |  1 | Variables         |       4 | DF Within Classes  |         31 |
# |  2 | Classes           |       3 | DF Between Classes |          2 |
#
# Class Level Information:
# |          |   Frequency |   Proportion |   Prior Probability |
# |----------|-------------|--------------|---------------------|
# | Mediocre |          12 |       0.3529 |              0.3529 |
# | Moyen    |          11 |       0.3235 |              0.3235 |
# | Bon      |          11 |       0.3235 |              0.3235 |
#
# Total-Sample Class Means:
# |             |   Mediocre |     Moyen |       Bon |
# |-------------|------------|-----------|-----------|
# | Temperature |  3037.33   | 3140.91   | 3306.36   |
# | Soleil      |  1126.42   | 1262.91   | 1363.64   |
# | Chaleur     |    12.0833 |   16.4545 |   28.5455 |
# | Pluie       |   430.333  |  339.636  |  305      |
#
# Importance of components:
# |      |   Eigenvalue |   Difference |   Proportion |   Cumulative |
# |------|--------------|--------------|--------------|--------------|
# | Can1 |       3.2789 |       3.1403 |      95.9451 |      95.9451 |
# | Can2 |       0.1386 |     nan      |       4.0549 |     100      |
#
# Raw Canonical and Classification Functions Coefficients:
# |             |     Can1 |    Can2 |   Mediocre |   Moyen |      Bon |
# |-------------|----------|---------|------------|---------|----------|
# | Constant    | -32.8763 |  2.1653 |    65.6093 | -7.1918 | -72.5905 |
# | Temperature |   0.0086 | -0      |    -0.0178 |  0.0013 |   0.0182 |
# | Soleil      |   0.0068 | -0.0053 |    -0.0153 |  0.0037 |   0.0129 |
# | Chaleur     |  -0.0271 |  0.1276 |     0.0845 | -0.0694 |  -0.0227 |
# | Pluie       |  -0.0059 |  0.0062 |     0.0136 | -0.004  |  -0.0108 |
#
# Test of H0: The canonical correlations in the current row and all that follow are zero
# |    |   Canonical Correlation |   Squared Canonical Correlation |   Likelihood Ratio |   Approximate F value |   Num DF |   Den DF |   Pr>F |   Chi-Square |   DF |   Pr>Chi2 |
# |----|-------------------------|---------------------------------|--------------------|-----------------------|----------|----------|--------|--------------|------|-----------|
# |  0 |                  0.8754 |                          0.7663 |             0.2053 |                8.4505 |        8 |       56 | 0      |      46.7122 |    8 |    0      |
# |  1 |                  0.3489 |                          0.1217 |             0.8783 |                1.3395 |        3 |       29 | 0.2808 |       3.8284 |    3 |    0.2806 |
#
# Classification Summary for Calibration Data:
#
# Observation Profile:
# |                        |   Read |   Used |
# |------------------------|--------|--------|
# | Number of Observations |     34 |     34 |
#
# Number of Observations Classified into Qualite:
# | Qualite   |   Mediocre |   Moyen |   Bon |   Total |
# |-----------|------------|---------|-------|---------|
# | Mediocre  |         10 |       2 |     0 |      12 |
# | Moyen     |          1 |       8 |     2 |      11 |
# | Bon       |          0 |       2 |     9 |      11 |
# | Total     |         11 |      12 |    11 |      34 |
#
# Percent Classified into Qualite:
# | Qualite   |   Mediocre |   Moyen |     Bon |   Total |
# |-----------|------------|---------|---------|---------|
# | Mediocre  |    83.3333 | 16.6667 |  0      |     100 |
# | Moyen     |     9.0909 | 72.7273 | 18.1818 |     100 |
# | Bon       |     0      | 18.1818 | 81.8182 |     100 |
# | Total     |    32.3529 | 35.2941 | 32.3529 |     100 |
# | Priors    |     0.3529 |  0.3235 |  0.3235 |     nan |
#
# Error Count Estimates for Qualite:
# |        |   Mediocre |   Moyen |    Bon |    Total |
# |--------|------------|---------|--------|----------|
# | Rate   |     0.1667 |  0.2727 | 0.1818 |   0.2059 |
# | Priors |     0.3529 |  0.3235 | 0.3235 | nan      |
#
# Classification Report for Qualite:
# |              |   precision |   recall |   f1-score |   support |
# |--------------|-------------|----------|------------|-----------|
# | Mediocre     |      0.9091 |   0.8333 |     0.8696 |   12      |
# | Moyen        |      0.6667 |   0.7273 |     0.6957 |   11      |
# | Bon          |      0.8182 |   0.8182 |     0.8182 |   11      |
# | accuracy     |      0.7941 |   0.7941 |     0.7941 |    0.7941 |
# | macro avg    |      0.798  |   0.7929 |     0.7945 |   34      |
# | weighted avg |      0.8012 |   0.7941 |     0.7967 |   34      |

# %% [markdown]
# ### Evaluation of prediction on testing dataset
#
# #### Testing data

# %%
#testining data
XTest = load_vins("test")
print_dt(XTest,rowname="Année",title=html("<b>Vins de Bordeaux testing data</b>"))
# Out:
# GT(_tbl_data=   Année  Temperature  Soleil  Chaleur  Pluie
# 0   1958         3000    1100       20    300, _body=<great_tables._gt_data.Body object at 0x00000181EC5EA8D0>, _boxhead=Boxhead([ColInfo(var='Année', type=<ColInfoTypeEnum.default: 1>, column_label='Année', column_align='right', column_width=None), ColInfo(var='Temperature', type=<ColInfoTypeEnum.default: 1>, column_label='Temperature', column_align='right', column_width=None), ColInfo(var='Soleil', type=<ColInfoTypeEnum.default: 1>, column_label='Soleil', column_align='right', column_width=None), ColInfo(var='Chaleur', type=<ColInfoTypeEnum.default: 1>, column_label='Chaleur', column_align='right', column_width=None), ColInfo(var='Pluie', type=<ColInfoTypeEnum.default: 1>, column_label='Pluie', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC591D50>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Vins de Bordeaux testing data</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC5E9BD0>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC5E8ED0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC5E8950>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_ba ...

# %% [markdown]
# #### `decision_function` function

# %%
#decision_function function
print_dt(clf.decision_function(XTest).head(),rowname="Année",title=html("<b>Decision function on testing data</b>"))
# Out:
# GT(_tbl_data=   Année  Mediocre   Moyen     Bon
# 0   1958   -1.1034 -4.0775 -9.7825, _body=<great_tables._gt_data.Body object at 0x00000181EC593AD0>, _boxhead=Boxhead([ColInfo(var='Année', type=<ColInfoTypeEnum.default: 1>, column_label='Année', column_align='right', column_width=None), ColInfo(var='Mediocre', type=<ColInfoTypeEnum.default: 1>, column_label='Mediocre', column_align='right', column_width=None), ColInfo(var='Moyen', type=<ColInfoTypeEnum.default: 1>, column_label='Moyen', column_align='right', column_width=None), ColInfo(var='Bon', type=<ColInfoTypeEnum.default: 1>, column_label='Bon', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA4FFC10>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Decision function on testing data</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC592F90>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC5E6850>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC5E6E50>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', t ...

# %% [markdown]
# #### `predict` function

# %%
#predict on testing data
print_dt(clf.predict(XTest).to_frame().head(),rowname="Année",title=html("<b>Prediction on testing data</b>"))
# Out:
# GT(_tbl_data=   Année prediction
# 0   1958   Mediocre, _body=<great_tables._gt_data.Body object at 0x00000181EA0BCE10>, _boxhead=Boxhead([ColInfo(var='Année', type=<ColInfoTypeEnum.default: 1>, column_label='Année', column_align='right', column_width=None), ColInfo(var='prediction', type=<ColInfoTypeEnum.default: 1>, column_label='prediction', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EA4E9790>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Prediction on testing data</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181E9DB0B10>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181E9DB2C90>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC58F5D0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=Opti ...

# %% [markdown]
# #### `predict_log_proba` function

# %%
#predict_log_proba function
print_dt(clf.predict_log_proba(XTest).head(),rowname="Année",title=html("<b>Estimated log-probabilities (test data)</b>"))
# Out:
# GT(_tbl_data=   Année  Mediocre   Moyen     Bon
# 0   1958     -0.05 -3.0241 -8.7291, _body=<great_tables._gt_data.Body object at 0x00000181EC523690>, _boxhead=Boxhead([ColInfo(var='Année', type=<ColInfoTypeEnum.default: 1>, column_label='Année', column_align='right', column_width=None), ColInfo(var='Mediocre', type=<ColInfoTypeEnum.default: 1>, column_label='Mediocre', column_align='right', column_width=None), ColInfo(var='Moyen', type=<ColInfoTypeEnum.default: 1>, column_label='Moyen', column_align='right', column_width=None), ColInfo(var='Bon', type=<ColInfoTypeEnum.default: 1>, column_label='Bon', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC5BE250>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Estimated log-probabilities (test data)</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC5200D0>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EA50BF50>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EA50BF10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='headi ...

# %% [markdown]
# #### `predict_proba` function

# %%
#predict_proba function
print_dt(clf.predict_proba(XTest).head(),rowname="Année",title=html("<b>Estimated probabilities (test data)</b>"))
# Out:
# GT(_tbl_data=   Année  Mediocre   Moyen     Bon
# 0   1958    0.9512  0.0486  0.0002, _body=<great_tables._gt_data.Body object at 0x00000181EC61DCD0>, _boxhead=Boxhead([ColInfo(var='Année', type=<ColInfoTypeEnum.default: 1>, column_label='Année', column_align='right', column_width=None), ColInfo(var='Mediocre', type=<ColInfoTypeEnum.default: 1>, column_label='Mediocre', column_align='right', column_width=None), ColInfo(var='Moyen', type=<ColInfoTypeEnum.default: 1>, column_label='Moyen', column_align='right', column_width=None), ColInfo(var='Bon', type=<ColInfoTypeEnum.default: 1>, column_label='Bon', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC61DD10>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Estimated probabilities (test data)</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC61C3D0>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC61C710>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC61C790>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', ...

# %% [markdown]
# #### `transform` function

# %%
#transform function
print_dt(clf.transform(XTest).head(),rowname="Année",title=html("<b>Transformed test data</b>"))
# Out:
# GT(_tbl_data=   Année    Can1    Can2
# 0   1958 -2.0277  0.5694, _body=<great_tables._gt_data.Body object at 0x00000181EC61CB10>, _boxhead=Boxhead([ColInfo(var='Année', type=<ColInfoTypeEnum.default: 1>, column_label='Année', column_align='right', column_width=None), ColInfo(var='Can1', type=<ColInfoTypeEnum.default: 1>, column_label='Can1', column_align='right', column_width=None), ColInfo(var='Can2', type=<ColInfoTypeEnum.default: 1>, column_label='Can2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000181EC613DD0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Transformed test data</b>'), subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x00000181EC5DB390>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x00000181EC5DB790>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x00000181EC5DB850>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight ...

# %% [markdown]
# ### `plotting` functions

# %%
#plotting
from discrimintools import fviz_candisc

# %% [markdown]
# #### Graph of individuals

# %%
#graph of individuals
p = fviz_candisc(clf,element="ind",repel=True)
print(p.show())
# Out:
# None

# %% [markdown]
# We add supplementary individuals to initial plot.

# %%
#with supplementary individuals
from discrimintools import add_scatter
p = add_scatter(p,clf.transform(XTest),color="blue",repel=True)
print(p.show())
# Out:
# None

# %% [markdown]
# #### Graph of variables

# %%
#graph of variables
print(fviz_candisc(clf,element="var",repel=True).show())
# Out:
# None

# %% [markdown]
# #### Biplot of individuals and variiables

# %%
#biplot of individuals and variables
p = fviz_candisc(clf,element="biplot",repel=True)
#add supplementary individuals
p = add_scatter(p,clf.transform(XTest),color="blue",repel=True)
print(p.show())
# Out:
# None

# %% [markdown]
# #### Distance between barycenter

# %%
#distance between barycenter
print(fviz_candisc(clf,element="dist",repel=True).show())
# Out:
# None
